# %% [markdown]
# # Practical 1 - Web Scrapping
#
# **Aim:** Perform HTML web scrapping.
#
# Place the notebook in the same folder where you want to save/run it. This notebook contains the HTML web scrapping code visible in the uploaded PDF.

# %%
# !pip install pandas beautifulsoup4 requests

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

url = "https://en.wikipedia.org/wiki/List_of_Asian_countries_by_area"
headers = {"User-Agent": "Mozilla/5.0"}
response = requests.get(url, headers=headers)
page = response.text

soup = BeautifulSoup(page, "html.parser")
table = soup.find("table")

srno = []
country = []
area = []

rows = table.find("tbody").find_all("tr")
for row in rows:
    cells = row.find_all("td")
    if cells:
        srno.append(cells[0].get_text().strip("\n"))
        country.append(cells[1].get_text().strip("\xa0").strip("\n"))
        area.append(cells[3].get_text().strip("\n").replace(",", ""))

df = pd.DataFrame()
df["SrNo"] = srno
df["Country"] = country
df["Area"] = area

print(df.head(10))

# %% [markdown]
# This program sends a request to a Wikipedia page, reads the HTML, and finds the first table.
# It extracts serial number, country name, and area row by row, stores them in lists, and converts them into a DataFrame.
# Finally, it prints the first 10 records so the scraped output can be checked quickly.

# %% [markdown]
# **Note:** The uploaded PDF showed the HTML web scrapping code, but the JSON web scrapping code was not visible in the source pages I could extract, so I did not invent a replacement here.
